# %% [markdown]
# #**Forward Selection**
# ---

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %%
df = pd.read_csv('loan_approval_dataset.csv')
df.drop('loan_id', axis=1, inplace=True)
df.head(5)
# Out:
#     no_of_dependents      education  self_employed   income_annum  \
# 0                  2       Graduate             No        9600000
# 1                  0   Not Graduate            Yes        4100000
# 2                  3       Graduate             No        9100000
# 3                  3       Graduate             No        8200000
# 4                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
le = LabelEncoder()

df[' education'] = le.fit_transform(df[' education'])
df[' self_employed'] = le.fit_transform(df[' self_employed'])
df[' loan_status'] = le.fit_transform(df[' loan_status'])

df.head(5)
# Out:
#     no_of_dependents   education   self_employed   income_annum   loan_amount  \
# 0                  2           0               0        9600000      29900000
# 1                  0           1               1        4100000      12200000
# 2                  3           0               0        9100000      29700000
# 3                  3           0               0        8200000      30700000
# 4                  5           1               1        9800000      24200000
#
#     loan_term   cibil_score   residential_assets_value  \
# 0          12           778                    2400000
# 1           8           417                    2700000
# 2          20           506                    7100000
# 3           8           467                   18200000
# 4          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#     loan_status
# 0             0
# 1             1
# 2             1
# 3             1
# 4             1

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.tree import DecisionTreeClassifier

# Define features and target variable
X = df.drop(columns=[' loan_status'])
y = df[' loan_status']

# Initialize the model
model = DecisionTreeClassifier(random_state=0)

# Perform forward selection
sfs = SFS(model,
          k_features=6,  # Select top 10 features
          forward=True,
          floating=False,
          scoring='accuracy',
          cv=5)


sfs = sfs.fit(X, y)

pd.DataFrame.from_dict(sfs.get_metric_dict()).T
# Out:
#           feature_idx                                          cv_scores  \
# 1                (6,)  [0.949648711943794, 0.936768149882904, 0.94613...
# 2              (5, 6)  [0.9578454332552693, 0.9484777517564403, 0.953...
# 3           (2, 5, 6)  [0.9578454332552693, 0.9519906323185011, 0.966...
# 4        (1, 2, 5, 6)  [0.955503512880562, 0.949648711943794, 0.96370...
# 5     (1, 2, 4, 5, 6)  [0.9613583138173302, 0.9508196721311475, 0.951...
# 6  (1, 2, 3, 4, 5, 6)  [0.9812646370023419, 0.9800936768149883, 0.983...
#
#   avg_score                                      feature_names  ci_bound  \
# 1  0.944484                                    ( cibil_score,)  0.005433
# 2  0.950808                         ( loan_term,  cibil_score)  0.006522
# 3  0.955961         ( self_employed,  loan_term,  cibil_score)  0.007352
# 4  0.955258  ( education,  self_employed,  loan_term,  cibi...  0.006135
# 5  0.955259  ( education,  self_employed,  loan_amount,  lo...  0.004792
# 6  0.982198  ( education,  self_employed,  income_annum,  l...   0.00175
#
#     std_dev   std_err
# 1  0.004227  0.002114
# 2  0.005075  0.002537
# 3   0.00572   0.00286
# 4  0.004773  0.002386
# 5  0.003729  0.001864
# 6  0.001362  0.000681

# %%
# Get selected features
selected_features = list(sfs.k_feature_names_)

print("Selected features (Decision Tree):")
print(selected_features)
# Out:
# Selected features (Decision Tree):
# [' education', ' self_employed', ' income_annum', ' loan_amount', ' loan_term', ' cibil_score']
